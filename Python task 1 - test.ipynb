# %% [markdown]
# ### Load Orders and Positions tables

# %% [markdown]
# I created 2 csv files to represent the orders and positions tables. For the purpose of this exercise, I generated some dummy data. In the positions table, the price of wine has been fixed at 10 CHF.  The foreign key is order_id.

# %% [markdown]
# To use the files, they must be imported and stored into a pandas DataFrame (similar to a SQL table).

# %%
# Import pandas library used for data analysis and manipulation

import pandas as pd

# %%
# Load and view orders.csv file

df_orders = pd.read_csv('orders.csv')
df_orders.head()
# Out:
#    order_id  order_version_id                 date  total  quantity  \
# 0         1                 1  2022-01-01 00:00:00    100        10
# 1         1                 2  2022-01-01 00:00:00     50         5
# 2         2                 1  2022-02-01 00:00:00    100        10
# 3         2                 2  2022-02-01 00:00:00     50         5
# 4         2                 3  2022-02-01 00:00:00    200        20
#
#             valid_from             valid_to
# 0  2022-01-01 00:00:00  2022-01-05 00:00:00
# 1  2022-01-05 00:00:00  9999-01-01 23:59:00
# 2  2022-01-01 00:00:00  2022-02-10 00:00:00
# 3  2022-02-10 00:00:00  2022-02-11 00:00:00
# 4  2022-02-11 00:00:00  9999-01-01 23:59:00

# %%
# Load and view positions.csv file 

df_positions = pd.read_csv('positions.csv')
df_positions.head()
# Out:
#    order_id  position_id  wine_id wine_name  quantity  price  \
# 0         1            1     1000       red         3     10
# 1         1            2     2000     white         2     10
# 2         2            2     2000     white         5     10
# 3         2            1     1000       red        10     10
# 4         2            3     3000   organic         5     10
#
#    netto_netto_price
# 0                  8
# 1                  9
# 2                  9
# 3                  8
# 4                  7

# %% [markdown]
# ### Show the last version of each order

# %% [markdown]
# #### Option 1 - using the valid_to column

# %%
# Since valid_to of the newest version of an order is set to a generic future datetime "9999-01-01 23:59:00", 
# we can use that value to filter the last order versions.

df_last_versions_1 = df_orders[df_orders['valid_to'] == "9999-01-01 23:59:00"] 
df_last_versions_1
# Out:
#     order_id  order_version_id                 date  total  quantity  \
# 1          1                 2  2022-01-01 00:00:00     50         5
# 4          2                 3  2022-02-01 00:00:00    200        20
# 5          3                 1  2022-03-10 00:00:00    100        10
# 8          4                 3  2022-04-10 00:00:00    200        20
# 11         5                 3  2022-05-02 00:00:00    250        25
# 12         6                 1  2022-05-14 00:00:00    300        30
#
#              valid_from             valid_to
# 1   2022-01-05 00:00:00  9999-01-01 23:59:00
# 4   2022-02-11 00:00:00  9999-01-01 23:59:00
# 5   2022-03-10 00:00:00  9999-01-01 23:59:00
# 8   2022-04-12 00:00:00  9999-01-01 23:59:00
# 11  2022-05-05 00:00:00  9999-01-01 23:59:00
# 12  2022-05-14 00:00:00  9999-01-01 23:59:00

# %% [markdown]
# #### Option 2 - based on maximum order_version_id number

# %%
# If we assume that the ids generated for each order version are sequential numbers, 
# we can filter the table based on the highest order_version_id number of each order. 

# Because order_version_id is type string, change the type of the column to int64
df_orders.astype({'order_version_id':'int64'})

# Group orders by order_id
grouped_orders = df_orders.groupby('order_id', as_index=False)

df_last_versions_2 = grouped_orders.apply(lambda df:df.sort_values('order_version_id', ascending=False).head(1)).droplevel(0)
df_last_versions_2
# Out:
#     order_id  order_version_id                 date  total  quantity  \
# 1          1                 2  2022-01-01 00:00:00     50         5
# 4          2                 3  2022-02-01 00:00:00    200        20
# 5          3                 1  2022-03-10 00:00:00    100        10
# 8          4                 3  2022-04-10 00:00:00    200        20
# 11         5                 3  2022-05-02 00:00:00    250        25
# 12         6                 1  2022-05-14 00:00:00    300        30
#
#              valid_from             valid_to
# 1   2022-01-05 00:00:00  9999-01-01 23:59:00
# 4   2022-02-11 00:00:00  9999-01-01 23:59:00
# 5   2022-03-10 00:00:00  9999-01-01 23:59:00
# 8   2022-04-12 00:00:00  9999-01-01 23:59:00
# 11  2022-05-05 00:00:00  9999-01-01 23:59:00
# 12  2022-05-14 00:00:00  9999-01-01 23:59:00

# %% [markdown]
# #### Option 2 - based on maximum valid_to date

# %%
# In case the valid_to date of the last order version is set to another specified date in the future, 
# instead of a fixed default value of 9999-1-1, we can find the maximum valid_to date in a table grouped
# by order_id. 

# Group orders by order_id
grouped_orders = df_orders.groupby('order_id', as_index=False)

df_last_versions_3 = grouped_orders.apply(lambda df:df.sort_values('valid_to', ascending=False).head(1)).droplevel(0)
df_last_versions_3
# Out:
#     order_id  order_version_id                 date  total  quantity  \
# 1          1                 2  2022-01-01 00:00:00     50         5
# 4          2                 3  2022-02-01 00:00:00    200        20
# 5          3                 1  2022-03-10 00:00:00    100        10
# 8          4                 3  2022-04-10 00:00:00    200        20
# 11         5                 3  2022-05-02 00:00:00    250        25
# 12         6                 1  2022-05-14 00:00:00    300        30
#
#              valid_from             valid_to
# 1   2022-01-05 00:00:00  9999-01-01 23:59:00
# 4   2022-02-11 00:00:00  9999-01-01 23:59:00
# 5   2022-03-10 00:00:00  9999-01-01 23:59:00
# 8   2022-04-12 00:00:00  9999-01-01 23:59:00
# 11  2022-05-05 00:00:00  9999-01-01 23:59:00
# 12  2022-05-14 00:00:00  9999-01-01 23:59:00

# %% [markdown]
# ### Show positions of the last version of each order

# %%
# Join tables to show the positions of the last order versions 

result = df_positions.merge(df_last_versions_1, on='order_id', how='left')
result.head()
# Out:
#    order_id  position_id  wine_id wine_name  quantity_x  price  \
# 0         1            1     1000       red           3     10
# 1         1            2     2000     white           2     10
# 2         2            2     2000     white           5     10
# 3         2            1     1000       red          10     10
# 4         2            3     3000   organic           5     10
#
#    netto_netto_price  order_version_id                 date  total  \
# 0                  8                 2  2022-01-01 00:00:00     50
# 1                  9                 2  2022-01-01 00:00:00     50
# 2                  9                 3  2022-02-01 00:00:00    200
# 3                  8                 3  2022-02-01 00:00:00    200
# 4                  7                 3  2022-02-01 00:00:00    200
#
#    quantity_y           valid_from             valid_to
# 0           5  2022-01-05 00:00:00  9999-01-01 23:59:00
# 1           5  2022-01-05 00:00:00  9999-01-01 23:59:00
# 2          20  2022-02-11 00:00:00  9999-01-01 23:59:00
# 3          20  2022-02-11 00:00:00  9999-01-01 23:59:00
# 4          20  2022-02-11 00:00:00  9999-01-01 23:59:00

# %%
# Clean the resulting view

# Rename columns that aren't straightforward and drop valid_to column, because it's irrelevant for this view
result.rename(columns = {'date':'date_of_order', 'quantity_x':'quantity', 'total': 'order_total', 
                         'quantity_y':'total_order_quantity'}, inplace=False).drop(columns = {'valid_to'}, 
                                                                                   axis=1, inplace=False)
# Out:
#     order_id  position_id  wine_id wine_name  quantity  price  \
# 0          1            1     1000       red         3     10
# 1          1            2     2000     white         2     10
# 2          2            2     2000     white         5     10
# 3          2            1     1000       red        10     10
# 4          2            3     3000   organic         5     10
# 5          3            1     2000     white         2     10
# 6          3            2     3000   organic         2     10
# 7          3            3     4000      rose         6     10
# 8          4            1     2000     white        10     10
# 9          4            2     3000   organic        10     10
# 10         5            2     1000       red        10     10
# 11         5            3     2000     white         8     10
# 12         5            1     3000   organic         2     10
# 13         5            4     4000      rose         5     10
# 14         6            1     1000       red        30     10
#
#     netto_netto_price  order_version_id        date_of_order  order_total  \
# 0                   8                 2  2022-01-01 00:00:00           50
# 1                   9                 2  2022-01-01 00:00:00           50
# 2                   9                 3  2022-02-01 00:00:00          200
# 3                   8                 3  2022-02-01 00:00:00          200
# 4                   7                 3  2022-02-01 00:00:00          200
# 5                   9                 1  2022-03-10 00:00:00          100
# 6                   7                 1  2022-03-10 00:00:00          100
# 7                   7                 1  2022-03-10 00:00:00          100
# 8                   9                 3  2022-04-10 00:00:00          200
# 9                   7                 3  2022-04-10 00:00:00          200
# 10                  8                 3  2022-05-02 00:00:00          250
# 11                  9                 3  2022-05-02 00:00:00          250
# 12                  7                 3  2022-05-02 00:00:00          250
# 13                  7                 3  2022-05-02 00:00:00          250
# 14                  8                 1  2022-05-14 00:00:00          300
#
#     total_order_quantity           valid_from
# 0                      5  2022-01-05 00:00:00
# 1                      5  2022-01-05 00:00:00
# 2                     20  2022-02-11 00:00:00
# 3                     20  2022-02-11 00:00:00
# 4                     20  2022-02-11 00:00:00
# 5                     10  2022-03-10 00:00:00
# 6                     10  2022-03-10 00:00:00
# 7                     10  2022-03-10 00:00:00
# 8                     20  2022-04-12 00:00:00
# 9                     20  2022-04-12 00:00:00
# 10                    25  2022-05-05 00:00:00
# 11                    25  2022-05-05 00:00:00
# 12                    25  2022-05-05 00:00:00
# 13                    25  2022-05-05 00:00:00
# 14                    30  2022-05-14 00:00:00

# %%
# Since the task consists of creating a function, for the purpose of this exercise, 
# I will create a function to complete the first part of the code above, 
# i.e. to filter the orders table to show only the last order versions. 

# An extended function would also take the Positions file/table as an argument, 
# and join the tables for a detailed view of the orders. 

import pandas as pd
from os.path import isfile

def show_last_order_versions(orders_file):
        
    try:    
        df_orders = pd.read_csv(orders_file)
        df_last_versions = df_orders[df_orders['valid_to'] == "9999-01-01 23:59:00"] 
        return df_last_versions
    except FileNotFoundError:
        print("File not found.")

# %%
show_last_order_versions("orders.csv")
# Out:
#     order_id  order_version_id                 date  total  quantity  \
# 1          1                 2  2022-01-01 00:00:00     50         5
# 4          2                 3  2022-02-01 00:00:00    200        20
# 5          3                 1  2022-03-10 00:00:00    100        10
# 8          4                 3  2022-04-10 00:00:00    200        20
# 11         5                 3  2022-05-02 00:00:00    250        25
# 12         6                 1  2022-05-14 00:00:00    300        30
#
#              valid_from             valid_to
# 1   2022-01-05 00:00:00  9999-01-01 23:59:00
# 4   2022-02-11 00:00:00  9999-01-01 23:59:00
# 5   2022-03-10 00:00:00  9999-01-01 23:59:00
# 8   2022-04-12 00:00:00  9999-01-01 23:59:00
# 11  2022-05-05 00:00:00  9999-01-01 23:59:00
# 12  2022-05-14 00:00:00  9999-01-01 23:59:00
